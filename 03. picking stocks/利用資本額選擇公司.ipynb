# %% [markdown]
# # 怎麼抓取公司資料？

# %%
import pandas as pd

# %%
def get_companies(ex = "NASDAQ"):
    template = "http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange={}&render=download"
    url = template.format(ex)
    return pd.read_csv(url)

# %%
data = get_companies("NYSE")

# %%
data[data['Symbol']=='AAPL']
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, LastSale, MarketCap, ADR TSO, IPOyear, Sector, Industry, Summary Quote, Unnamed: 9]
# Index: []

# %%
data.head()
# Out:
#   Symbol                    Name  LastSale     MarketCap  ADR TSO  IPOyear  \
# 0    DDD  3D Systems Corporation     20.91  2.384373e+09      NaN      NaN
# 1    MMM              3M Company    205.29  1.204259e+11      NaN      NaN
# 2   WBAI         500.com Limited     13.08  5.526984e+08      NaN   2013.0
# 3   WUBA             58.com Inc.     72.50  1.069299e+10      NaN   2013.0
# 4   EGHT                 8x8 Inc     22.70  2.118407e+09      NaN      NaN
#
#               Sector                                         Industry  \
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4   Public Utilities                     Telecommunications Equipment
#
#                         Summary Quote  Unnamed: 9
# 0   https://www.nasdaq.com/symbol/ddd         NaN
# 1   https://www.nasdaq.com/symbol/mmm         NaN
# 2  https://www.nasdaq.com/symbol/wbai         NaN
# 3  https://www.nasdaq.com/symbol/wuba         NaN
# 4  https://www.nasdaq.com/symbol/eght         NaN

# %%
data[data['MarketCap'] < 1e8].head()
# Out:
#    Symbol                                           Name  LastSale  \
# 5     AHC                          A.H. Belo Corporation      4.50
# 23    ATV                      Acorn International, Inc.     18.72
# 40    LCM  Advent/Claymore Enhanced Growth & Income Fund      7.74
# 42    ANW           Aegean Marine Petroleum Network Inc.      1.90
# 43    AEB                                       Aegon NV     25.32
#
#       MarketCap  ADR TSO  IPOyear             Sector                Industry  \
# 5   97635159.00      NaN      NaN  Consumer Services    Newspapers/Magazines
# 23  50172220.80      NaN   2007.0  Consumer Services  Other Specialty Stores
# 40  71068997.34      NaN   2005.0                NaN                     NaN
# 42  77216801.80      NaN   2006.0             Energy  Oil Refining/Marketing
# 43         0.00      NaN      NaN            Finance          Life Insurance
#
#                         Summary Quote  Unnamed: 9
# 5   https://www.nasdaq.com/symbol/ahc         NaN
# 23  https://www.nasdaq.com/symbol/atv         NaN
# 40  https://www.nasdaq.com/symbol/lcm         NaN
# 42  https://www.nasdaq.com/symbol/anw         NaN
# 43  https://www.nasdaq.com/symbol/aeb         NaN
